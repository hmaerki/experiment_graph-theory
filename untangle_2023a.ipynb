# %%
from untangle import untangle_2023a as u

u.doit()

# %%
from untangle import untangle_2023a as u

STR_GAME_6A = "6:0-1,0-3,0-4,1-2,1-3,1-5,2-3,2-5,3-4"

g = u.create_graph(u.STR_GAME_6A)
u.set_xy(g, '0', 4.0, 2.0)
u.set_xy(g, '1', 2.0, 3.0)
u.set_xy(g, '2', 3.0, 6.0)
u.set_xy(g, '3', 7.0, 5.0)
u.set_xy(g, '4', 10.0, 3.0)
u.set_xy(g, '5', 0.0, 5.0)

plot = u.plot_2d(graph=g, edges=True)
# plot.show()

# for n in sorted(g.nodes()):
#     print(n)
# for e in sorted(g.edges()):
#     print(e)
